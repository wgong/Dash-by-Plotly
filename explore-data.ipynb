# %%
import pandas as pd

# %% [markdown]
# This dataset is used by `Dash_Interactive_Graphs/bar.py`

# %%
data_path = "./Dash_Interactive_Graphs/Urban_Park_Ranger_Animal_Condition_Response.csv.gz"
df = pd.read_csv(data_path, compression='gzip')

# %%
df.shape, df.columns
# Out:
# ((982, 22),
#  Index(['Date and Time of initial call', 'Date and time of Ranger response',
#         'Borough', 'Property', 'Location', 'Species Description', 'Call Source',
#         'Species Status', 'Animal Condition', 'Duration of Response', 'Age',
#         'Animal Class', '311SR Number', 'Final Ranger Action', '# of Animals',
#         'PEP Response', 'Animal Monitored', 'Rehabilitator',
#         'Hours spent monitoring', 'Police Response', 'ESU Response',
#         'ACC Intake Number'],
#        dtype='object'))

# %%
df[:5]
# Out:
#   Date and Time of initial call Date and time of Ranger response  \
# 0                11/9/2018 9:00                  11/9/2018 10:15
# 1              11/30/2018 11:00                 11/30/2018 13:45
# 2              11/10/2018 15:00                 11/10/2018 15:10
# 3                9/4/2018 14:30                   9/4/2018 15:50
# 4                 6/9/2019 9:30                   6/9/2019 10:00
#
#          Borough                                     Property  \
# 0       Brooklyn                               Bushwick Inlet
# 1      Manhattan                             Inwood Hill Park
# 2      Manhattan                             Inwood Hill Park
# 3  Staten Island  Ocean Breeze Track & Field Athletic Complex
# 4       Brooklyn                                Parade Ground
#
#                                           Location    Species Description  \
# 0                              Bushwick Inlet Park  Chinese Silky Chicken
# 1                             M & O HQ District 12                Chicken
# 2                               Dykman Ball Fields                Chicken
# 3                     Father Capodanno and Seaview              Rock Dove
# 4  Prospect Park Parade Grounds near Tennis Center                Chicken
#
#   Call Source Species Status Animal Condition  Duration of Response  ...  \
# 0    Employee         Exotic          Healthy                  1.25  ...
# 1    Employee       Domestic          Healthy                  1.00  ...
# 2    Employee       Domestic          Healthy                  1.50  ...
# 3    Employee         Native          Healthy                  2.50  ...
# 4     Central       Domestic          Healthy                  3.00  ...
#
#      311SR Number Final Ranger Action # of Animals PEP Response  \
# 0  1-1-1642034010  Animal Care Center          1.0        False
# 1  1-1-1647471950  Animal Care Center          1.0        False
# 2  1-1-1642034151  Animal Care Center          1.0        False
# 3  1-1-1613258011  Animal Care Center          1.0         True
# 4  1-1-1730643971  Animal Care Center          1.0        False
#
#    Animal Monitored Rehabilitator  Hours spent monitoring Police Response  \
# 0             False           NaN                     NaN           False
# 1             False           NaN                     NaN           False
# 2             False           NaN                     NaN           False
# 3             False           NaN                     NaN           False
# 4             False           NaN                     NaN           False
#
#    ESU Response ACC Intake Number
# 0         False             46854
# 1         False             48438
# 2         False             46961
# 3         False             40608
# 4         False             65352
#
# [5 rows x 22 columns]

# %%
df['# of Animals'].head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: # of Animals, dtype: float64

# %%
df[df['# of Animals'] <= 0].head()
# Out:
#     Date and Time of initial call Date and time of Ranger response    Borough  \
# 272                12/3/2018 9:00                   12/3/2018 9:00  Manhattan
# 427                8/22/2018 9:00                  8/22/2018 10:00   Brooklyn
# 429               10/1/2018 11:00                  10/1/2018 11:10     Queens
# 443               7/26/2018 12:30                  7/26/2018 13:00  Manhattan
# 455               5/15/2019 11:30                  5/16/2019 11:00  Manhattan
#
#                        Property                                    Location  \
# 272  Jacob H. Schiff Playground                           W 136 & Amsterdam
# 427           Cadman Plaza Park                                War Memorial
# 429                 Forest Park                                 Golf course
# 443                Central Park                            Rumsey Playfield
# 455        Fort Washington Park  Lily Brown Playground, 915 Riverside Drive
#
#     Species Description Call Source Species Status Animal Condition  \
# 272             Raccoon    Employee         Native          No data
# 427             Raccoon    Employee         Native          Healthy
# 429             raccoon      Public         Native          Healthy
# 443             Raccoon    Employee         Native          Injured
# 455             No data     Central         Native          No data
#
#      Duration of Response  ...    311SR Number      Final Ranger Action  \
# 272                   0.5  ...             NaN  Advised/Educated others
# 427                   0.5  ...             NaN                Unfounded
# 429                   0.5  ...             NaN                Unfounded
# 443                   2.0  ...             NaN                Unfounded
# 455                   1.0  ...  1-1-1721158092                Unfounded
#
#     # of Animals PEP Response  Animal Monitored Rehabilitator  \
# 272          0.0        False             False           NaN
# 427          0.0        False             False           NaN
# 429          0.0        False             False           NaN
# 443          0.0        False             False           NaN
# 455          0.0        False             False           NaN
#
#      Hours spent monitoring Police Response  ESU Response ACC Intake Number
# 272                     NaN           False         False               NaN
# 427                     NaN           False         False               NaN
# 429                     NaN           False         False               NaN
# 443                     NaN           False         False               NaN
# 455                     NaN           False         False               NaN
#
# [5 rows x 22 columns]

# %%
# Drop rows w/ no animals found or calls w/ varied age groups
df = df[(df['# of Animals']>0) & (df['Age']!='Multiple')]

# Extract month from time call made to Ranger
df['Month of Initial Call'] = pd.to_datetime(df['Date and Time of initial call'])
df['Month of Initial Call'] = df['Month of Initial Call'].dt.strftime('%m')

# Copy columns to new columns with clearer names
df['Amount of Animals'] = df['# of Animals']
df['Time Spent on Site (hours)'] = df['Duration of Response']
